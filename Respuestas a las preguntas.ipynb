# %% [markdown]
# ## ACTIVIDAD 2: CLASIFICACIÓN DE TEXTO
# ### Marta Alejandra Llanos Rodríguez

# %% [markdown]
# En este último documento encontraremos las respuestas a las preguntas. Empezamos cargando los 4 datasets realizados en los anteriores notebooks

# %%
import pandas as pd

# %%
Modelos_100f_stop = pd.read_csv('Modelos_100f_stop.csv')
Modelos_100f_sinstop = pd.read_csv('Modelos_100f_sinstop.csv')
Modelos_75f_stop = pd.read_csv('Modelos_75f_stop.csv')
Modelos_75f_sinstop = pd.read_csv('Modelos_75f_sinstop.csv')

# %%
Modelos_100f_sinstop
# Out:
#               Modelo  Acc entrenamiento  Acc test  Fiabilidad  \
# 0        Naive Bayes              0.942     0.934       0.992
# 1                SVM              0.970     0.962       0.992
# 2  Árbol de Decisión              0.997     0.953       0.957
# 3      Random Forest              0.995     0.966       0.971
#
#    Verdaderos Positivos  Falsos Positivos  Falsos Negativos  \
# 0                  1189                 4                88
# 1                  1182                11                42
# 2                  1162                31                34
# 3                  1189                 4                44
#
#    Verdaderos Negativos
# 0                   112
# 1                   158
# 2                   166
# 3                   156

# %%
Modelos_75f_stop
# Out:
#               Modelo  Acc entrenamiento  Acc test  Fiabilidad  \
# 0        Naive Bayes              0.956     0.940       0.984
# 1                SVM              0.962     0.948       0.985
# 2  Árbol de Decisión              0.983     0.956       0.973
# 3      Random Forest              0.983     0.962       0.979
#
#    Verdaderos Positivos  Falsos Positivos  Falsos Negativos  \
# 0                  1177                16                67
# 1                  1170                23                49
# 2                  1169                24                37
# 3                  1175                18                35
#
#    Verdaderos Negativos
# 0                   133
# 1                   151
# 2                   163
# 3                   165

# %%
Modelos_75f_sinstop
# Out:
#               Modelo  Acc entrenamiento  Acc test  Fiabilidad  \
# 0        Naive Bayes              0.928     0.918       0.989
# 1                SVM              0.964     0.952       0.987
# 2  Árbol de Decisión              0.996     0.950       0.954
# 3      Random Forest              0.993     0.955       0.962
#
#    Verdaderos Positivos  Falsos Positivos  Falsos Negativos  \
# 0                  1190                 3               111
# 1                  1181                12                55
# 2                  1160                33                37
# 3                  1184                 9                53
#
#    Verdaderos Negativos
# 0                    89
# 1                   145
# 2                   163
# 3                   147

# %% [markdown]
# ### 6. Pregunta 6:  ¿Tiene influencia en el resultado final el número máximo de features a utilizar? ¿Modifica el resultado si no se eliminan las stop words?

# %% [markdown]
# Entre los modelos en los que comparamos cambiando el número de features vemos que en general clasifica mejor si tiene más features en los modelos naive bayes y svm, sin embargo en los árboles de decisión tiene una fiabilidad mayor, por lo que clasifica mejor. (comparación Modelos_100f_stop y Modelos_75f_stop).

# %% [markdown]
# En cambio, si comparamos la eliminación de stop words, todos los modelos tienen una mejor fiabilidad si eliminamos las stopwords. (comparación Modelos_100f_stop y Modelos_100f_sinstop).

# %%
Modelos_100f_stop
# Out:
#               Modelo  Acc entrenamiento  Acc test  Fiabilidad  \
# 0        Naive Bayes              0.961     0.949       0.988
# 1                SVM              0.969     0.956       0.987
# 2  Árbol de Decisión              0.985     0.952       0.966
# 3      Random Forest              0.983     0.962       0.978
#
#    Verdaderos Positivos  Falsos Positivos  Falsos Negativos  \
# 0                  1179                14                57
# 1                  1173                20                41
# 2                  1165                28                39
# 3                  1176                17                36
#
#    Verdaderos Negativos
# 0                   143
# 1                   159
# 2                   161
# 3                   164

# %% [markdown]
# ### 7. Pregunta 7:  Resultados

# %% [markdown]
# Si nos quedamos con el primer modelo que realizamos: Modelo_100f_Stop, vemos que en general los modelos Naive Bayes y SVM tienen mejor resultado en cuanto a fiabilidad que los entrenados con modelos de árboles de decisión.
#
# Comprobamos además que los primeros modelos (Naive y SVM) clasifican mejor los verdaderos positivos, aquellos emails que no son spam, mientras que los arboles clasifican mejor los verdaderos negativos, aquellos que efectivamente son spam.
